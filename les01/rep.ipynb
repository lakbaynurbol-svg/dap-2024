# %% [markdown]
# <a href="https://colab.research.google.com/github/lakbaynurbol-svg/dap-2024/blob/main/les01/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Лабораторная работа №1
## Подготовка среды для анализа данных


## Цель работы
Освоить базовые инструменты для анализа данных: GitHub, Google Colab, интеграцию между ними и оформление отчёта в Jupyter Notebook.


## Задания
1. Создать учётную запись в GitHub.
2. Выполнить форк репозитория [dap-2024](https://github.com/chebotarevsa/dap-2024).
3. Создать учётную запись в Google Colab.
4. Настроить интеграцию Google Colab и GitHub.
5. Создать отчёт `rep.ipynb` в Colab с использованием Markdown.
6. Сохранить отчёт в свой форк в директории `./les01`.
7. Создать Pull Request в основной репозиторий.
8. Сдать работу в системе «Пегас», указав ссылку на Pull Request.


## Ход выполнения
- Зарегистрирован аккаунт в GitHub.
- Выполнен форк репозитория `dap-2024`.
- Создан аккаунт в Google Colab.
- Настроена интеграция Colab ↔ GitHub.
- Создан и заполнен отчёт `rep.ipynb`.
- Файл сохранён в директории `les01`.
- Создан Pull Request в основной репозиторий.


## Ответы на вопросы

### Типы ячеек в Jupyter Notebook
- **Code** — выполнение кода.
- **Markdown** — текст, заголовки, списки, формулы.
- **Raw** — необработанный текст.

### Иерархический список в Markdown
```markdown
- Первый уровень
  - Второй уровень
    - Третий уровень

### Уровни заголовков в Markdown
Существует 6 уровней: `#` до `######`.

### Шаги анализа данных (подробно про очистку данных)
- Сбор данных
- Очистка и подготовка (удаление пропусков, нормализация, кодирование категорий)
- Исследовательский анализ (EDA)
- Моделирование
- Визуализация и интерпретация
- Репортинг

**Очистка данных:** удаление дубликатов, обработка пропусков, приведение типов, нормализация признаков.

### Типы данных (подробно про категориальные)
- Числовые, строковые, булевы, даты/время, категориальные.
**Категориальные:** конечный набор значений (например, города). Используются для группировки и кодирования (one-hot, target encoding).

### Что такое Jupyter Notebook
Интерактивная среда для анализа данных, объединяющая код, текст и визуализацию.

### Почему Python популярен для анализа данных
- Простота синтаксиса.
- Огромная экосистема библиотек (NumPy, Pandas, Scikit-learn).
- Активное сообщество.

### Обязательно ли использовать Jupyter Notebook?
Нет, можно работать в IDE (VS Code, PyCharm) или использовать скрипты. Но Jupyter удобен для обучения и отчётов.

## Ссылка на Pull Request
[Мой Pull Request](сюда вставь ссылку после создания)

## Выводы
В ходе работы настроена среда для анализа данных, выполнена интеграция GitHub ↔ Google Colab, создан отчёт и отправлен Pull Request.
