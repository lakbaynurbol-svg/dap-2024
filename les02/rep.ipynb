# %% [markdown]
# <a href="https://colab.research.google.com/github/lakbaynurbol-svg/dap-2024/blob/main/les02/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Лабораторная работа №2
## Основы Python


## Цель работы
Закрепить базовые навыки программирования на Python через решение задач и ответы на теоретические вопросы.


## Задания
1. Открыть файл в Google Colab (использовать собственный форк репозитория).
2. Решить предложенные задачи.
3. Сохранить результат в свой репозиторий GitHub в директорию `./les02`.
4. Создать Pull Request в основной репозиторий.
5. Сдать работу в системе «Пегас», указав ссылку на Pull Request.


## Ход выполнения
- Открыт форк репозитория `dap-2024`.
- Создан ноутбук `rep.ipynb` в Google Colab.
- Реализованы решения задач №1–6.
- Файл сохранён в директории `les02`.
- Создан Pull Request в основной репозиторий.


## Решения задач

# %%
### Задача №1. Two Sum
class Solution1(object):
    def twoSum(self, nums, target):
        hashmap = {}
        for i, num in enumerate(nums):
            diff = target - num
            if diff in hashmap:
                return [hashmap[diff], i]
            hashmap[num] = i

# %%
### Задача №2. Palindrome Number
class Solution2(object):
    def isPalindrome(self, x):
        return str(x) == str(x)[::-1]

# %%
### Задача №3. Roman to Integer
class Solution3(object):
    def romanToInt(self, s):
        values = {'I':1,'V':5,'X':10,'L':50,'C':100,'D':500,'M':1000}
        total = 0
        prev = 0
        for ch in reversed(s):
            val = values[ch]
            if val < prev:
                total -= val
            else:
                total += val
            prev = val
        return total

# %%
### Задача №4. Longest Common Prefix
class Solution4(object):
    def longestCommonPrefix(self, strs):
        if not strs:
            return ""
        prefix = strs[0]
        for s in strs[1:]:
            while not s.startswith(prefix):
                prefix = prefix[:-1]
                if not prefix:
                    return ""
        return prefix

# %%
### Задача №5. Merge Two Sorted Lists
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution5(object):
    def mergeTwoLists(self, list1, list2):
        dummy = ListNode()
        tail = dummy
        while list1 and list2:
            if list1.val < list2.val:
                tail.next = list1
                list1 = list1.next
            else:
                tail.next = list2
                list2 = list2.next
            tail = tail.next
        tail.next = list1 or list2
        return dummy.next

# %%
### Задача №6. Longest Substring Without Repeating Characters
class Solution(object):
    def lengthOfLongestSubstring(self, s):
        seen = {}
        left = 0
        max_len = 0
        for right, ch in enumerate(s):
            if ch in seen and seen[ch] >= left:
                left = seen[ch] + 1
            seen[ch] = right
            max_len = max(max_len, right - left + 1)
        return max_len

# %%
###
Ответы на вопросы по Лабораторной работе №2

1. Что такое динамическая типизация и чем она отличается от статической?
   - Динамическая типизация: тип переменной определяется во время выполнения (Python).
   - Статическая типизация: тип переменной задаётся при компиляции (C++, Java).

2. Чем отличается цикл for в Python от цикла for в C++?
   - В Python for перебирает элементы коллекции напрямую.
   - В C++ for чаще работает с индексами или итераторами.

3. Для чего предназначены операторы continue и break?
   - continue: пропускает текущую итерацию и переходит к следующей.
   - break: завершает выполнение цикла полностью.

4. Как определить функцию в Python? Может ли функция возвращать несколько значений?
   - Определение: через ключевое слово def.
   - Да, функция может возвращать несколько значений (как кортеж).
   Пример:
   def my_func(a, b):
       return a, b

5. Что такое лямбда-функции и для чего они предназначены?
   - Короткие анонимные функции для одноразовых вычислений.
   Пример: f = lambda x: x**2

6. Может ли тело функции содержать определение другой функции?
   - Да, можно создавать вложенные функции (замыкания).

7. Как определить класс в Python? Для чего нужна переменная self?
   - Класс определяется через class.
   - self — ссылка на текущий экземпляр класса.
   Пример:
   class MyClass:
       def __init__(self, val):
           self.val = val

8. Как определить приватный метод? Можно ли вызвать приватный метод за пределами класса?
   - Приватный метод начинается с __ (name mangling).
   - Вызвать можно через _ClassName__method, но это нарушает инкапсуляцию.

9. Как определить статический метод класса? Для чего может понадобиться статический метод?
   - Используется декоратор @staticmethod.
   - Нужен для вспомогательных функций, не зависящих от состояния объекта.
   Пример:
   class C:
       @staticmethod
       def add(a, b): return a + b

10. Чем staticmethod отличается от classmethod?
    - staticmethod: обычная функция внутри класса, не принимает self или cls.
    - classmethod: принимает cls и работает с самим классом.

11. Как определить собственный класс исключений Python? Как выбросить и перехватить исключение?
    - Наследуемся от Exception.
    - Выбрасываем через raise, ловим через try/except.
    Пример:
    class MyError(Exception):
        pass

    try:
        raise MyError("Ошибка")
    except MyError as e:
        print("Поймано:", e)

12. Что такое кортеж, для чего он используется?
    - Кортеж (tuple) — неизменяемая последовательность.
    - Используется для хранения фиксированных наборов данных и множественного возврата из функций.
    Пример: t = (1, 2, 3)
###
# Out:
#   File "/tmp/ipython-input-4202978439.py", line 5
#     - Динамическая типизация: тип переменной определяется во время выполнения (Python).
#     ^
# IndentationError: unexpected indent
